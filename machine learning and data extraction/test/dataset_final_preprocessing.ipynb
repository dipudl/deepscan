# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("c_operator_expression_dataset_460k.csv", sep="\t")

# %%
df
# Out:
#                                        operator_expression  \
# 0                                        ( index + 1 ) % 4
# 1                                            index + 1 % 4
# 2                            ( 1 << FIX_DECIMAL ) * shrink
# 3                                1 << FIX_DECIMAL * shrink
# 4                            ( 1 << FIX_DECIMAL ) * shrink
# ...                                                    ...
# 2067090                          len < 0 && errno == EINTR
# 2067091                      len < ( 0 && ) errno == EINTR
# 2067092                  alt && key_code == KEY_VOLUMEDOWN
# 2067093              ( alt && key_code ) == KEY_VOLUMEDOWN
# 2067094  get_allow_toggle_display ( ) && ( key_code == ...
#
#                                                  file_path  \
# 0                           cleaned/meridian59/club/util.c
# 1                           cleaned/meridian59/club/util.c
# 2                          cleaned/meridian59/bbgun/draw.c
# 3                          cleaned/meridian59/bbgun/draw.c
# 4                          cleaned/meridian59/bbgun/draw.c
# ...                                                    ...
# 2067090  cleaned/android_device_samsung_p4-common/power...
# 2067091  cleaned/android_device_samsung_p4-common/power...
# 2067092  cleaned/android_device_samsung_p4-common/recov...
# 2067093  cleaned/android_device_samsung_p4-common/recov...
# 2067094  cleaned/android_device_samsung_p4-common/recov...
#
#                        method  label
# 0          parenthsis_removal      0
# 1          parenthsis_removal      1
# 2          parenthsis_removal      0
# 3          parenthsis_removal      1
# 4          parenthsis_removal      0
# ...                       ...    ...
# 2067090  parenthsis_insertion      0
# 2067091  parenthsis_insertion      1
# 2067092  parenthsis_insertion      0
# 2067093  parenthsis_insertion      1
# 2067094  parenthsis_insertion      0
#
# [2067095 rows x 4 columns]

# %%
# rename column from "label" to "labels"
df = df.rename(columns={"label": "labels"})

# %%
df = df.drop(df.index[-1])
df
# Out:
#                            operator_expression  \
# 0                            ( index + 1 ) % 4
# 1                                index + 1 % 4
# 2                ( 1 << FIX_DECIMAL ) * shrink
# 3                    1 << FIX_DECIMAL * shrink
# 4                ( 1 << FIX_DECIMAL ) * shrink
# ...                                        ...
# 2067089                  ( fn == nfields ) + 1
# 2067090              len < 0 && errno == EINTR
# 2067091          len < ( 0 && ) errno == EINTR
# 2067092      alt && key_code == KEY_VOLUMEDOWN
# 2067093  ( alt && key_code ) == KEY_VOLUMEDOWN
#
#                                                  file_path  \
# 0                           cleaned/meridian59/club/util.c
# 1                           cleaned/meridian59/club/util.c
# 2                          cleaned/meridian59/bbgun/draw.c
# 3                          cleaned/meridian59/bbgun/draw.c
# 4                          cleaned/meridian59/bbgun/draw.c
# ...                                                    ...
# 2067089                          cleaned/waspvm/rx/split.c
# 2067090  cleaned/android_device_samsung_p4-common/power...
# 2067091  cleaned/android_device_samsung_p4-common/power...
# 2067092  cleaned/android_device_samsung_p4-common/recov...
# 2067093  cleaned/android_device_samsung_p4-common/recov...
#
#                        method  labels
# 0          parenthsis_removal       0
# 1          parenthsis_removal       1
# 2          parenthsis_removal       0
# 3          parenthsis_removal       1
# 4          parenthsis_removal       0
# ...                       ...     ...
# 2067089  parenthsis_insertion       1
# 2067090  parenthsis_insertion       0
# 2067091  parenthsis_insertion       1
# 2067092  parenthsis_insertion       0
# 2067093  parenthsis_insertion       1
#
# [2067094 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# operator_expression    0
# file_path              0
# method                 0
# labels                 0
# dtype: int64

# %%
df["method"].value_counts()
# Out:
# parenthsis_insertion    1193318
# parenthsis_removal       873776
# Name: method, dtype: int64

# %%
df["operator_expression"].nunique()
# Out:
# 479438

# %%
df = df.drop_duplicates(subset=['operator_expression'])
# Resetting the index
df = df.reset_index(drop=True)

# %%
df
# Out:
#                                       operator_expression  \
# 0                                       ( index + 1 ) % 4
# 1                                           index + 1 % 4
# 2                           ( 1 << FIX_DECIMAL ) * shrink
# 3                               1 << FIX_DECIMAL * shrink
# 4       ( ( int ) ( ( OFFSCREEN_BITMAP_SIZE - x - 1 ) ...
# ...                                                   ...
# 479433                     ( ct + 1 ) * sizeof ( char * )
# 479434                         ct + 1 * sizeof ( char * )
# 479435  sub . rm_so > ( sub . rm_eo || ( ( sub . rm_so...
# 479436                  alt && key_code == KEY_VOLUMEDOWN
# 479437              ( alt && key_code ) == KEY_VOLUMEDOWN
#
#                                                 file_path  \
# 0                          cleaned/meridian59/club/util.c
# 1                          cleaned/meridian59/club/util.c
# 2                         cleaned/meridian59/bbgun/draw.c
# 3                         cleaned/meridian59/bbgun/draw.c
# 4                         cleaned/meridian59/bbgun/draw.c
# ...                                                   ...
# 479433                          cleaned/waspvm/vm/shell.c
# 479434                          cleaned/waspvm/vm/shell.c
# 479435                           cleaned/waspvm/rx/main.c
# 479436  cleaned/android_device_samsung_p4-common/recov...
# 479437  cleaned/android_device_samsung_p4-common/recov...
#
#                       method  labels
# 0         parenthsis_removal       0
# 1         parenthsis_removal       1
# 2         parenthsis_removal       0
# 3         parenthsis_removal       1
# 4         parenthsis_removal       0
# ...                      ...     ...
# 479433    parenthsis_removal       0
# 479434    parenthsis_removal       1
# 479435  parenthsis_insertion       1
# 479436  parenthsis_insertion       0
# 479437  parenthsis_insertion       1
#
# [479438 rows x 4 columns]

# %%
def count_words(text):
    words = text.split()
    return len(words)

df["word_count"] = df["operator_expression"].apply(count_words)

df["word_count"].mean()
# Out:
# 13.541542389214039

# %%
(df["word_count"] > 100).sum()
# Out:
# 692

# %%
"""Remove operator expression containing more than 100 words"""

df["word_count"] = df["operator_expression"].apply(count_words)

# Filter rows where word count is less than or equal to 100
df_filtered = df[df["word_count"] <= 100]

# Drop the 'word_count' column as it's no longer needed
df_filtered = df_filtered.drop(columns=['word_count'])

# %%
df_filtered = df_filtered.reset_index(drop=True)
df_filtered
# Out:
#                                       operator_expression  \
# 0                                       ( index + 1 ) % 4
# 1                                           index + 1 % 4
# 2                           ( 1 << FIX_DECIMAL ) * shrink
# 3                               1 << FIX_DECIMAL * shrink
# 4       ( ( int ) ( ( OFFSCREEN_BITMAP_SIZE - x - 1 ) ...
# ...                                                   ...
# 478741                     ( ct + 1 ) * sizeof ( char * )
# 478742                         ct + 1 * sizeof ( char * )
# 478743  sub . rm_so > ( sub . rm_eo || ( ( sub . rm_so...
# 478744                  alt && key_code == KEY_VOLUMEDOWN
# 478745              ( alt && key_code ) == KEY_VOLUMEDOWN
#
#                                                 file_path  \
# 0                          cleaned/meridian59/club/util.c
# 1                          cleaned/meridian59/club/util.c
# 2                         cleaned/meridian59/bbgun/draw.c
# 3                         cleaned/meridian59/bbgun/draw.c
# 4                         cleaned/meridian59/bbgun/draw.c
# ...                                                   ...
# 478741                          cleaned/waspvm/vm/shell.c
# 478742                          cleaned/waspvm/vm/shell.c
# 478743                           cleaned/waspvm/rx/main.c
# 478744  cleaned/android_device_samsung_p4-common/recov...
# 478745  cleaned/android_device_samsung_p4-common/recov...
#
#                       method  labels
# 0         parenthsis_removal       0
# 1         parenthsis_removal       1
# 2         parenthsis_removal       0
# 3         parenthsis_removal       1
# 4         parenthsis_removal       0
# ...                      ...     ...
# 478741    parenthsis_removal       0
# 478742    parenthsis_removal       1
# 478743  parenthsis_insertion       1
# 478744  parenthsis_insertion       0
# 478745  parenthsis_insertion       1
#
# [478746 rows x 4 columns]

# %%
df_filtered.to_csv("operator_precedence_bug_dataset____k_preprocessed.tsv", sep="\t", index=False)

# %% [markdown]
# ---
# ## Rough
# ---

# %%
custom_df = pd.read_csv("operator_precedence_bug_dataset.csv", sep="\t")

# %%
custom_df
# Out:
#                                        operator_expression  \
# 0                                        ( index + 1 ) % 4
# 1                                            index + 1 % 4
# 2                            ( 1 << FIX_DECIMAL ) * shrink
# 3                                1 << FIX_DECIMAL * shrink
# 4                            ( 1 << FIX_DECIMAL ) * shrink
# ...                                                    ...
# 2271780  ( flags & GLOB_DOOFFS ) && pglob -> gl_offs > ...
# 2271781  ( ( flags & GLOB_DOOFFS ) && pglob -> gl_offs ...
# 2271782                        ! ( flags & GLOB_NOESCAPE )
# 2271783                    flags & ! flags & GLOB_NOESCAPE
# 2271784            flags & ( GLOB_NOCHECK | GLOB_NOMAGIC )
#
#                                                  file_path  \
# 0                           cleaned/meridian59/club/util.c
# 1                           cleaned/meridian59/club/util.c
# 2                          cleaned/meridian59/bbgun/draw.c
# 3                          cleaned/meridian59/bbgun/draw.c
# 4                          cleaned/meridian59/bbgun/draw.c
# ...                                                    ...
# 2271780  cleaned/platform_external/systemtap/target/run...
# 2271781  cleaned/platform_external/systemtap/target/run...
# 2271782  cleaned/platform_external/systemtap/target/run...
# 2271783  cleaned/platform_external/systemtap/target/run...
# 2271784  cleaned/platform_external/systemtap/target/run...
#
#                        method  label
# 0          parenthsis_removal      0
# 1          parenthsis_removal      1
# 2          parenthsis_removal      0
# 3          parenthsis_removal      1
# 4          parenthsis_removal      0
# ...                       ...    ...
# 2271780  parenthsis_insertion      0
# 2271781  parenthsis_insertion      1
# 2271782    parenthsis_removal      0
# 2271783    parenthsis_removal      1
# 2271784    parenthsis_removal      0
#
# [2271785 rows x 4 columns]

# %%
# Currently: Total files: 479000 , Total samples: 2135272
# Next: Total files: 505000 , Total samples: 101302

custom_df = custom_df.head(2135274+101302)

# %%
custom_df
# Out:
#                                        operator_expression  \
# 0                                        ( index + 1 ) % 4
# 1                                            index + 1 % 4
# 2                            ( 1 << FIX_DECIMAL ) * shrink
# 3                                1 << FIX_DECIMAL * shrink
# 4                            ( 1 << FIX_DECIMAL ) * shrink
# ...                                                    ...
# 2236571                   regnum == ( - 1 || regnum == i )
# 2236572  creal ( z__ ) != ( float ) 0. || cimag ( z__ )...
# 2236573  ( creal ( z__ ) != ( ( float ) 0. || cimag ( z...
# 2236574  creal ( z__ ) != ( float ) 0. || cimag ( z__ )...
# 2236575  ( creal ( z__ ) != ( ( float ) 0. || cimag ( z...
#
#                                                  file_path  \
# 0                           cleaned/meridian59/club/util.c
# 1                           cleaned/meridian59/club/util.c
# 2                          cleaned/meridian59/bbgun/draw.c
# 3                          cleaned/meridian59/bbgun/draw.c
# 4                          cleaned/meridian59/bbgun/draw.c
# ...                                                    ...
# 2236571  cleaned/dports/devel/gdb66/dragonfly/amd64dfly...
# 2236572       cleaned/dports/science/linsmith/files/carg.c
# 2236573       cleaned/dports/science/linsmith/files/carg.c
# 2236574            cleaned/dports/comms/nec2c/files/carg.c
# 2236575            cleaned/dports/comms/nec2c/files/carg.c
#
#                        method  label
# 0          parenthsis_removal      0
# 1          parenthsis_removal      1
# 2          parenthsis_removal      0
# 3          parenthsis_removal      1
# 4          parenthsis_removal      0
# ...                       ...    ...
# 2236571  parenthsis_insertion      1
# 2236572  parenthsis_insertion      0
# 2236573  parenthsis_insertion      1
# 2236574  parenthsis_insertion      0
# 2236575  parenthsis_insertion      1
#
# [2236576 rows x 4 columns]

# %%
custom_df.to_csv("operator_precedence_bug_dataset.csv", index=False, sep="\t")

# %%
pd.read_csv("operator_precedence_bug_dataset.csv", sep="\t")
# Out:
#                                        operator_expression  \
# 0                                        ( index + 1 ) % 4
# 1                                            index + 1 % 4
# 2                            ( 1 << FIX_DECIMAL ) * shrink
# 3                                1 << FIX_DECIMAL * shrink
# 4                            ( 1 << FIX_DECIMAL ) * shrink
# ...                                                    ...
# 2236832                       optlen <= 0 || optlen > olen
# 2236833                   ( optlen <= 0 || optlen ) > olen
# 2236834  strlen ( ifn ) == sdl -> sdl_nlen && strncmp (...
# 2236835  ( strlen ( ifn ) == ( sdl -> sdl_nlen && strnc...
# 2236836                             argc != 1 && argc != 3
#
#                                             file_path                method  \
# 0                      cleaned/meridian59/club/util.c    parenthsis_removal
# 1                      cleaned/meridian59/club/util.c    parenthsis_removal
# 2                     cleaned/meridian59/bbgun/draw.c    parenthsis_removal
# 3                     cleaned/meridian59/bbgun/draw.c    parenthsis_removal
# 4                     cleaned/meridian59/bbgun/draw.c    parenthsis_removal
# ...                                               ...                   ...
# 2236832      cleaned/dports/net/tcpmssd/src/tcpmssd.c  parenthsis_insertion
# 2236833      cleaned/dports/net/tcpmssd/src/tcpmssd.c  parenthsis_insertion
# 2236834      cleaned/dports/net/tcpmssd/src/tcpmssd.c  parenthsis_insertion
# 2236835      cleaned/dports/net/tcpmssd/src/tcpmssd.c  parenthsis_insertion
# 2236836  cleaned/dports/x11/xvmcinfo/files/xvmcinfo.c  parenthsis_insertion
#
#          label
# 0            0
# 1            1
# 2            0
# 3            1
# 4            0
# ...        ...
# 2236832      0
# 2236833      1
# 2236834      0
# 2236835      1
# 2236836      0
#
# [2236837 rows x 4 columns]
